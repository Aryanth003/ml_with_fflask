# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanth003/ml_with_fflask/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/customers-100.csv')

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
# prompt: genrate two dataframes to practice merge in pandas with coustomer

import pandas as pd

# Assuming df is already defined from the previous code block
# Create the first DataFrame
customer_data1 = {
    'customer_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'city': ['New York', 'London', 'Paris', 'Tokyo', 'Sydney']
}
df1 = pd.DataFrame(customer_data1)

# Create the second DataFrame
customer_data2 = {
    'customer_id': [3, 4, 5, 6, 7],
    'age': [25, 30, 28, 22, 24],
    'country': ['USA', 'UK', 'France', 'Japan', 'Australia']
}
df2 = pd.DataFrame(customer_data2)

# Print both dataframes
print("DataFrame 1:")
print(df1)
print("\nDataFrame 2:")
df2
# Out:
# DataFrame 1:
#    customer_id     name      city
# 0            1    Alice  New York
# 1            2      Bob    London
# 2            3  Charlie     Paris
# 3            4    David     Tokyo
# 4            5      Eve    Sydney
#
# DataFrame 2:
#    customer_id  age    country
# 0            3   25        USA
# 1            4   30         UK
# 2            5   28     France
# 3            6   22      Japan
# 4            7   24  Australia

# %%
data={"product_name":["pathanjali","adidas",'nike',"apple"],"custmer":["arya","tarun",'damera',"burra"]}
d2={"product_name":["pathanjali","adidas",'nike',"apple"],"price":[12,23,34,45]}
a=pd.DataFrame(data)
b=pd.DataFrame(d2)
pd.merge(a,b,on="product_name")
# Out:
#   product_name custmer  price
# 0   pathanjali    arya     12
# 1       adidas   tarun     23
# 2         nike  damera     34
# 3        apple   burra     45
