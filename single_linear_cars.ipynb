# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanth003/ml_with_fflask/blob/main/single_linear_cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Cars.csv")

# %%
# Out:
# <ipython-input-40-d0dbb7002515>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['VOL']>90]['VOL']="HIGH"
#        HP    MPG    VOL     SP     WT
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 76  False  False  False  False  False
# 77  False  False  False  False  False
# 78  False  False  False  False  False
# 79  False  False  False  False  False
# 80  False  False  False  False  False
#
# [81 rows x 5 columns]

# %%
correlation = df['HP'].corr(df['SP'])
print(f"The correlation between hp and mpg is: {correlation}\n\n\n")

plt.figure(figsize=(8, 6))
sns.scatterplot(x='HP', y='SP', data=df)
plt.title('hp vs SP')
plt.xlabel('Horsepower')
plt.ylabel('SP')
plt.show()
# Out:
# The correlation between hp and mpg is: 0.9738480721866618

# %%
import statsmodels.formula.api as sm
model=sm.ols(formula="SP~HP",data=df).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     SP   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     1451.
# Date:                Sat, 01 Feb 2025   Prob (F-statistic):           1.32e-52
# Time:                        07:25:31   Log-Likelihood:                -209.20
# No. Observations:                  81   AIC:                             422.4
# Df Residuals:                      79   BIC:                             427.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     93.1352      0.828    112.473      0.000      91.487      94.783
# ...
